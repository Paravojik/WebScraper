# %% [markdown]
# # Packages import

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import json
import os

# %% [markdown]
# # Ceneo Scraper

# %% [markdown]
# 1. Provide url of the product's opinions page

# %%
product_code="173381730"
page=1
url= f"https://www.ceneo.pl/{product_code}/opinie-{page}"

# %% [markdown]
# 2. Send request to provided url

# %%
path_to_driver = "D:\\chromedriver-win64\\chromedriver.exe"
s = Service(path_to_driver)
driver = webdriver.Chrome(service=s)
driver.get(url)
driver.maximize_window()
driver.find_element(by="xpath",value="//*[@id='js_cookie-consent-general']/div/div[2]/button[1]").click()

# %%
r=requests.get(url)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# 3. Fetch product name

# %%
page_dom=BeautifulSoup(r.text, 'html.parser')
print(type(page_dom))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
product_name=page_dom.select_one('h1').get_text()
print(product_name)
print(type(product_name))
# Out:
# Office 2024 Professional Plus
# <class 'str'>

# %% [markdown]
# ----
# ---

# %% [markdown]
# # my Idea(some useless)

# %%
if r.status_code==200:
    # print(r.content)
    # soup=BeautifulSoup(r.content,'html.parser')
    reviews=page_dom.find_all('div',{"class":"user-post user-post__card js_product-review"})
    # soup2=BeautifulSoup(reviews,'html.parser')
    for review in reviews:
        print(review.find('div',{'class':"user-post__text"}).get_text())
else:
    print('Error')
# Out:
# Aktywacja przebiegła pomyślnie lecz nie obyło się bez aktywacji telefonicznej.
# Produkt to LTSC i aktywacja jest dosyć uciążliwa ale działa i o to chodzi.
# Aktywacja przebiegła sprawnie office aktywował się poprawnie wersja 2024 wszystko zgodnie z opisem. Nie miałem żadnych problemów podczas aktywacji klucza licencyjnego, aktywacja telefoniczna, przez telefon można wybrać opcję aktywacji przez stronę internetową otrzymuje się wtedy wiadomość SMS z linkiem do strony internetowej na której odbywa się aktywacja.
# Nigdzie w opisie czy w tytule nie zająknęli się że to wersja LTSC. Następnie sklep twierdzi że klucz jest z aktywacją online... Taka to online aktywacja, że w instrukcji aktywacji którą przysyłają z kluczem jest napisane "wybierz "Aktywacja przez Telefon" Wybierz region - Polska" i masz wysłać sprzedawcy ID instalacji który wygeneruje w get cid ID aktywacji i wyślę emailem....
# Oszustwo!! Dostajecie kod produktu i link do jakiejś lewej, zapewne pirackiej strony, a na pewno nie mającej nic wspólnego z MS. Trzeba być kretynem żeby w takie linki klikać a co dopiero pobierać z nich cokolwiek. W opisie wyraźnie napisana jest informacja o aktywacji online, a w mailu instrukcja do aktywacji telefonicznej. Przestrzegam
# Kupiłem dwa klucze office 2024 pro. Wysłali mi 2x ten sam klucz. Klucz się nie aktywował automatycznie bo przekroczono liczbę aktywacji.
# Później pomogli mi z aktywacją telefoniczną (oni ją omijają jakimś programem i wysyłają kod aktywacji) i pewnie byłbym zadowolony bo office się aktywował na obu komputerach. Ale jak sprawdziłem w powershell jaką mam licencję to się okazało że obie to nie jest wersja Pro, tylko 2024 LTSC. Ponadto jedna licencja to Retail ale druga to Preview Beta z automatycznym wygaśnięciem za 3 lata. Gdy zalogowałem się do konta Microsoft to obie licencję zaczęły wyświetlać że są już nie ważne. Nie polecam produktu. Szkoda czasu. Niby sprzedawca oferuje pomoc przez email ale mało się zna, i nie potrafi rozwiązać kłopotów jakie wywołał tym pirackim kluczem. Rozwiązali mi je dopiero ludzie z massgrave i TSForge.
# Uwaga nie jest to normalna wersja tylko ltsc. Różnica między Office LTSC a normalnym Office (np. Microsoft 365 lub Office 2024/2021) polega głównie na modelu aktualizacji i funkcjach: Normalny Office (M365/2024) otrzymuje regularne aktualizacje funkcji i jest oparty na chmurze z funkcjami AI, podczas gdy Office LTSC (Long-Term Servicing Channel) to jednorazowy zakup dla firm, oferujący stały, stabilny zestaw funkcji (*****, Excel, PowerPoint, Outlook), tylko aktualizacje zabezpieczeń i poprawki, bez nowych funkcji i usług chmurowych jak w normalnej wersji.
# Nie można zainstalować z podanego linku.
# Najpierw wystawiłam złą ocenę z powodu ostrzeżeń antywirusa. Sprzedawca zapewnił mnie, że z programem jest wszystko w porządku. Dałam się przekonać, pobrałam go i usunęłam ocenę. Po pewnym czasie używania okazało się jednak, że oprogramowanie jest fałszywe i przestało działać. Pojawia się komunikat, że muszę połączyć komputer z siecią firmową, aby wykonać aktywację, ponieważ to oprogramowanie nie jest do użytku domowego. W sytuacji, gdy zostało zakupione do domu, oznacza to, że jest fałszywe i muszę zmienić klucz produktu. Program po prostu nie działa.
# Otrzymana wersja to LTSC

# %%
if r.status_code==200:
    # print(r.content)
    # soup=BeautifulSoup(r.content,'html.parser')
    reviews=page_dom.select_one("div.js_product-reviews.js_reviews-hook.js_product-reviews-container")
    reviews=reviews.select("div.user-post.user-post__card.js_product-review")
    # soup2=BeautifulSoup(reviews,'html.parser')
  
    for review in reviews:
        print(review.select_one("div.user-post__text").get_text())
else:
    print('Error')
# Out:
# Aktywacja przebiegła pomyślnie lecz nie obyło się bez aktywacji telefonicznej.
# Produkt to LTSC i aktywacja jest dosyć uciążliwa ale działa i o to chodzi.
# Aktywacja przebiegła sprawnie office aktywował się poprawnie wersja 2024 wszystko zgodnie z opisem. Nie miałem żadnych problemów podczas aktywacji klucza licencyjnego, aktywacja telefoniczna, przez telefon można wybrać opcję aktywacji przez stronę internetową otrzymuje się wtedy wiadomość SMS z linkiem do strony internetowej na której odbywa się aktywacja.
# Nigdzie w opisie czy w tytule nie zająknęli się że to wersja LTSC. Następnie sklep twierdzi że klucz jest z aktywacją online... Taka to online aktywacja, że w instrukcji aktywacji którą przysyłają z kluczem jest napisane "wybierz "Aktywacja przez Telefon" Wybierz region - Polska" i masz wysłać sprzedawcy ID instalacji który wygeneruje w get cid ID aktywacji i wyślę emailem....
# Oszustwo!! Dostajecie kod produktu i link do jakiejś lewej, zapewne pirackiej strony, a na pewno nie mającej nic wspólnego z MS. Trzeba być kretynem żeby w takie linki klikać a co dopiero pobierać z nich cokolwiek. W opisie wyraźnie napisana jest informacja o aktywacji online, a w mailu instrukcja do aktywacji telefonicznej. Przestrzegam
# Kupiłem dwa klucze office 2024 pro. Wysłali mi 2x ten sam klucz. Klucz się nie aktywował automatycznie bo przekroczono liczbę aktywacji.
# Później pomogli mi z aktywacją telefoniczną (oni ją omijają jakimś programem i wysyłają kod aktywacji) i pewnie byłbym zadowolony bo office się aktywował na obu komputerach. Ale jak sprawdziłem w powershell jaką mam licencję to się okazało że obie to nie jest wersja Pro, tylko 2024 LTSC. Ponadto jedna licencja to Retail ale druga to Preview Beta z automatycznym wygaśnięciem za 3 lata. Gdy zalogowałem się do konta Microsoft to obie licencję zaczęły wyświetlać że są już nie ważne. Nie polecam produktu. Szkoda czasu. Niby sprzedawca oferuje pomoc przez email ale mało się zna, i nie potrafi rozwiązać kłopotów jakie wywołał tym pirackim kluczem. Rozwiązali mi je dopiero ludzie z massgrave i TSForge.
# Uwaga nie jest to normalna wersja tylko ltsc. Różnica między Office LTSC a normalnym Office (np. Microsoft 365 lub Office 2024/2021) polega głównie na modelu aktualizacji i funkcjach: Normalny Office (M365/2024) otrzymuje regularne aktualizacje funkcji i jest oparty na chmurze z funkcjami AI, podczas gdy Office LTSC (Long-Term Servicing Channel) to jednorazowy zakup dla firm, oferujący stały, stabilny zestaw funkcji (*****, Excel, PowerPoint, Outlook), tylko aktualizacje zabezpieczeń i poprawki, bez nowych funkcji i usług chmurowych jak w normalnej wersji.
# Nie można zainstalować z podanego linku.
# Najpierw wystawiłam złą ocenę z powodu ostrzeżeń antywirusa. Sprzedawca zapewnił mnie, że z programem jest wszystko w porządku. Dałam się przekonać, pobrałam go i usunęłam ocenę. Po pewnym czasie używania okazało się jednak, że oprogramowanie jest fałszywe i przestało działać. Pojawia się komunikat, że muszę połączyć komputer z siecią firmową, aby wykonać aktywację, ponieważ to oprogramowanie nie jest do użytku domowego. W sytuacji, gdy zostało zakupione do domu, oznacza to, że jest fałszywe i muszę zmienić klucz produktu. Program po prostu nie działa.
# Otrzymana wersja to LTSC

# %%
opinions=page_dom.find_all('div',class_='js_product-review')
print(type(opinions))
print(len(opinions))
# Out:
# <class 'bs4.element.ResultSet'>
# 11

# %% [markdown]
# --------
# ---

# %% [markdown]
# 4. Fetch all opinions from the webpage

# %%
opinions=page_dom.select('div.js_product-review:not(.user-post--highlight)')
print(type(opinions))
print(len(opinions))
# Out:
# <class 'bs4.element.ResultSet'>
# 10

# %% [markdown]
# 5. Parse opinions to extract required data

# %%
all_opinions=[]

for opinion in opinions:
    single_opinion={
        "opinion_id":opinion.get('data-entry-id'),
        "author":opinion.select_one(".user-post__author-name").get_text().strip(),
        "recommendation":opinion.select_one(".user-post__author-recomendation").get_text().strip() if opinion.select_one(".user-post__author-recomendation") else None,
        "score":opinion.select_one(".user-post__score-count").get_text().strip(),
        "content":opinion.select_one(".user-post__text").get_text().strip(),
        "pros":[opinion.get_text().strip() for opinion in opinion.select(".review-feature__item--positive")],
        "cons":[opinion.get_text().strip() for opinion in opinion.select(".review-feature__item--negative")],
        "helpful":opinion.select_one(".vote-yes").get('data-vote'),
        "unhelpful":opinion.select_one(".vote-no").get('data-vote'),
        "publish_date":opinion.select_one(".user-post__published time:nth-child(1)").get('datetime').strip() if opinion.select_one(".user-post__published time:nth-child(1)").get('datetime') else None,
        "purchase_date":opinion.select_one(".user-post__published time:nth-child(1)").get('datetime').strip() if opinion.select_one(".user-post__published time:nth-child(1)").get('datetime') else None,

    }
    print(single_opinion)
    all_opinions.append(single_opinion)


    # print(single_opinion)
    # print(opinion.get('data-entry-id'))
    # print(opinion.select_one(".user-post__author-name").get_text())
    # print(opinion.select_one(".user-post__author-recomendation").get_text())
    # print(opinion.select_one(".user-post__score-count").get_text())
    # print(opinion.select_one(".user-post__text").get_text())
    # print(opinion.select(".review-feature__item--positive"))
    # print(opinion.select(".review-feature__item--negative"))
    # print(opinion.select_one(".vote-yes").get('data-vote'))
    # print(opinion.select_one(".vote-no").get('data-vote'))
    # print(opinion.select_one(".user-post__published time:nth-child(1)").get('datetime'))
    # print(opinion.select_one(".user-post__published time:last-of-type").get('datetime'))


print(all_opinions)
# Out:
# {'opinion_id': '20455380', 'author': 'Gajos', 'recommendation': 'Polecam', 'score': '5/5', 'content': 'Aktywacja przebiegła pomyślnie lecz nie obyło się bez aktywacji telefonicznej.', 'pros': ['cena', 'funkcjonalność', 'łatwość obsługi', 'możliwości'], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-04-13 04:37:21', 'purchase_date': '2026-04-13 04:37:21'}
# {'opinion_id': '20154746', 'author': 'RAFAŁ', 'recommendation': 'Polecam', 'score': '5/5', 'content': 'Produkt to LTSC i aktywacja jest dosyć uciążliwa ale działa i o to chodzi.', 'pros': ['funkcjonalność', 'łatwość obsługi', 'możliwości'], 'cons': ['trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-12-16 14:16:44', 'purchase_date': '2025-12-16 14:16:44'}
# {'opinion_id': '20490175', 'author': 'Piotr', 'recommendation': 'Polecam', 'score': '5/5', 'content': 'Gitara.Kolejny klucz/Licencja z tego sklepu zakupiony', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-04-27 11:00:59', 'purchase_date': '2026-04-27 11:00:59'}
# {'opinion_id': '20279077', 'author': 'Piotr', 'recommendation': None, 'score': '3/5', 'content': 'Otrzymana wersja to LTSC', 'pros': [], 'cons': ['funkcjonalność', 'łatwość obsługi', 'możliwości', 'trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-02-09 09:40:51', 'purchase_date': '2026-02-09 09:40:51'}
# {'opinion_id': '20175666', 'author': 'fueldo', 'recommendation': 'Nie polecam', 'score': '1/5', 'content': 'Nigdzie w opisie czy w tytule nie zająknęli się że to wersja LTSC. Następnie sklep twierdzi że klucz jest z aktywacją online... Taka to online aktywacja, że w instrukcji aktywacji którą przysyłają z kluczem jest napisane "wybierz "Aktywacja przez Telefon" Wybierz region - Polska" i masz wysłać sprzedawcy ID instalacji który wygeneruje w get cid ID aktywacji i wyślę emailem....', 'pros': [], 'cons': ['funkcjonalność', 'łatwość obsługi', 'możliwości', 'trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-12-25 16:25:14', 'purchase_date': '2025-12-25 16:25:14'}
# {'opinion_id': '20060311', 'author': 'Marcin', 'recommendation': 'Nie polecam', 'score': '0,5/5', 'content': 'Oszustwo!! Dostajecie kod produktu i link do jakiejś lewej, zapewne pirackiej strony, a na pewno nie mającej nic wspólnego z MS. Trzeba być kretynem żeby w takie linki klikać a co dopiero pobierać z nich cokolwiek. W opisie wyraźnie napisana jest informacja o aktywacji online, a w mailu instrukcja do aktywacji telefonicznej. Przestrzegam', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-11-03 18:38:42', 'purchase_date': '2025-11-03 18:38:42'}
# {'opinion_id': '20327035', 'author': 's...i', 'recommendation': 'Nie polecam', 'score': '1/5', 'content': 'Kupiłem dwa klucze office 2024 pro. Wysłali mi 2x ten sam klucz. Klucz się nie aktywował automatycznie bo przekroczono liczbę aktywacji. \nPóźniej pomogli mi z aktywacją telefoniczną (oni ją omijają jakimś programem i wysyłają kod aktywacji) i pewnie byłbym zadowolony bo office się aktywował na obu komputerach. Ale jak sprawdziłem w powershell jaką mam licencję to się okazało że obie to nie jest wersja Pro, tylko 2024 LTSC. Ponadto jedna licencja to Retail ale druga to Preview Beta z automatycznym wygaśnięciem za 3 lata. Gdy zalogowałem się do konta Microsoft to obie licencję zaczęły wyświetlać że są już nie ważne. Nie polecam produktu. Szkoda czasu. Niby sprzedawca oferuje pomoc przez email ale mało się zna, i nie potrafi rozwiązać kłopotów jakie wywołał tym pirackim kluczem. Rozwiązali mi je dopiero ludzie z massgrave i TSForge.', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-02-24 09:01:02', 'purchase_date': '2026-02-24 09:01:02'}
# {'opinion_id': '20147853', 'author': 'Krzysztof', 'recommendation': 'Nie polecam', 'score': '0,5/5', 'content': 'Uwaga nie jest to normalna wersja tylko ltsc. Różnica między Office LTSC a normalnym Office (np. Microsoft 365 lub Office 2024/2021) polega głównie na modelu aktualizacji i funkcjach: Normalny Office (M365/2024) otrzymuje regularne aktualizacje funkcji i jest oparty na chmurze z funkcjami AI, podczas gdy Office LTSC (Long-Term Servicing Channel) to jednorazowy zakup dla firm, oferujący stały, stabilny zestaw funkcji (*****, Excel, PowerPoint, Outlook), tylko aktualizacje zabezpieczeń i poprawki, bez nowych funkcji i usług chmurowych jak w normalnej wersji.', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-12-13 09:01:59', 'purchase_date': '2025-12-13 09:01:59'}
# {'opinion_id': '20073442', 'author': 'j...s', 'recommendation': 'Nie polecam', 'score': '0,5/5', 'content': 'Nie można zainstalować z podanego linku.', 'pros': [], 'cons': ['funkcjonalność', 'łatwość obsługi', 'możliwości', 'trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-11-10 09:25:34', 'purchase_date': '2025-11-10 09:25:34'}
# {'opinion_id': '20410093', 'author': 'vangeriss', 'recommendation': 'Nie polecam', 'score': '1/5', 'content': 'Najpierw wystawiłam złą ocenę z powodu ostrzeżeń antywirusa. Sprzedawca zapewnił mnie, że z programem jest wszystko w porządku. Dałam się przekonać, pobrałam go i usunęłam ocenę. Po pewnym czasie używania okazało się jednak, że oprogramowanie jest fałszywe i przestało działać. Pojawia się komunikat, że muszę połączyć komputer z siecią firmową, aby wykonać aktywację, ponieważ to oprogramowanie nie jest do użytku domowego. W sytuacji, gdy zostało zakupione do domu, oznacza to, że jest fałszywe i muszę zmienić klucz produktu. Program po prostu nie działa.', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-03-25 14:48:10', 'purchase_date': '2026-03-25 14:48:10'}
# [{'opinion_id': '20455380', 'author': 'Gajos', 'recommendation': 'Polecam', 'score': '5/5', 'content': 'Aktywacja przebiegła pomyślnie lecz nie obyło się bez aktywacji telefonicznej.', 'pros': ['cena', 'funkcjonalność', 'łatwość obsługi', 'możliwości'], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-04-13 04:37:21', 'purchase_date': '2026-04-13 04:37:21'}, {'opinion_id': '20154746', 'author': 'RAFAŁ', 'recommendation': 'Polecam', 'score': '5/5', 'content': 'Produkt to LTSC i aktywacja jest dosyć uciążliwa ale działa i o to chodzi.', 'pros': ['funkcjonalność', 'łatwość obsługi', 'możliwości'], 'cons': ['trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-12-16 14:16:44', 'purchase_date': '2025-12-16 14:16:44'}, {'opinion_id': '20490175', 'author': 'Piotr', 'recommendation': 'Polecam', 'score': '5/5', 'content': 'Gitara.Kolejny klucz/Licencja z tego sklepu zakupiony', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-04-27 11:00:59', 'purchase_date': '2026-04-27 11:00:59'}, {'opinion_id': '20279077', 'author': 'Piotr', 'recommendation': None, 'score': '3/5', 'content': 'Otrzymana wersja to LTSC', 'pros': [], 'cons': ['funkcjonalność', 'łatwość obsługi', 'możliwości', 'trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-02-09 09:40:51', 'purchase_date': '2026-02-09 09:40:51'}, {'opinion_id': '20175666', 'author': 'fueldo', 'recommendation': 'Nie polecam', 'score': '1/5', 'content': 'Nigdzie w opisie czy w tytule nie zająknęli się że to wersja LTSC. Następnie sklep twierdzi że klucz jest z aktywacją online... Taka to online aktywacja, że w instrukcji aktywacji którą przysyłają z kluczem jest napisane "wybierz "Aktywacja przez Telefon" Wybierz region - Polska" i masz wysłać sprzedawcy ID instalacji który wygeneruje w get cid ID aktywacji i wyślę emailem....', 'pros': [], 'cons': ['funkcjonalność', 'łatwość obsługi', 'możliwości', 'trudność instalacji'], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-12-25 16:25:14', 'purchase_date': '2025-12-25 16:25:14'}, {'opinion_id': '20060311', 'author': 'Marcin', 'recommendation': 'Nie polecam', 'score': '0,5/5', 'content': 'Oszustwo!! Dostajecie kod produktu i link do jakiejś lewej, zapewne pirackiej strony, a na pewno nie mającej nic wspólnego z MS. Trzeba być kretynem żeby w takie linki klikać a co dopiero pobierać z nich cokolwiek. W opisie wyraźnie napisana jest informacja o aktywacji online, a w mailu instrukcja do aktywacji telefonicznej. Przestrzegam', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2025-11-03 18:38:42', 'purchase_date': '2025-11-03 18:38:42'}, {'opinion_id': '20327035', 'author': 's...i', 'recommendation': 'Nie polecam', 'score': '1/5', 'content': 'Kupiłem dwa klucze office 2024 pro. Wysłali mi 2x ten sam klucz. Klucz się nie aktywował automatycznie bo przekroczono liczbę aktywacji. \nPóźniej pomogli mi z aktywacją telefoniczną (oni ją omijają jakimś programem i wysyłają kod aktywacji) i pewnie byłbym zadowolony bo office się aktywował na obu komputerach. Ale jak sprawdziłem w powershell jaką mam licencję to się okazało że obie to nie jest wersja Pro, tylko 2024 LTSC. Ponadto jedna licencja to Retail ale druga to Preview Beta z automatycznym wygaśnięciem za 3 lata. Gdy zalogowałem się do konta Microsoft to obie licencję zaczęły wyświetlać że są już nie ważne. Nie polecam produktu. Szkoda czasu. Niby sprzedawca oferuje pomoc przez email ale mało się zna, i nie potrafi rozwiązać kłopotów jakie wywołał tym pirackim kluczem. Rozwiązali mi je dopiero ludzie z massgrave i TSForge.', 'pros': [], 'cons': [], 'helpful': '1', 'unhelpful': '0', 'publish_date': '2026-02-24 09:01:02', 'purchase_date': '2026-02-24 09:01:02'}, {'opinion_id': '20147853', 'author': 'Krzysztof', 'recommendation': 'Nie polecam', 'score': '0,5/5', 'content': 'Uwaga nie jest to normalna wersja tylko ltsc. Różnica między Office LTSC a normalnym Office (np. Microsoft  ...

# %% [markdown]
# 6. Check if there is a next page with opinions

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
driver.find_element(by="xpath",value="//*[@id='reviews']/div/div[7]/button[4]").click()




next = True if page_dom.select_one("button.pagination__next") else False
if next: page+=1
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 driver.find_element(by="xpath",value="//*[@id='reviews']/div/div[7]/button[4]").click()
#       6 next = True if page_dom.select_one("button.pagination__next") else False
#       7 if next: page+=1
#
# File d:\243239\WebScraper\.venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:114, in WebElement.click(self)
#     107 def click(self) -> None:
#     108     """Clicks the element.
#     109
#     110     Example:
#     111         element = driver.find_element(By.ID, "foo")
#     112         element.click()
#     113     """
# --> 114     self._execute(Command.CLICK_ELEMENT)
#
# File d:\243239\WebScraper\.venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# --> 508 return self._parent.execute(command, params)
#
# File d:\243239\WebScraper\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File d:\243239\WebScraper\.venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button aria-label="Następna" class="pagination__item pagination__next obfuscated-link js_obfuscated-link" data-hash="LzE3MzM4MTczMC9vcGluaWUtMg==" type="button"></button> is not clickable at point (1654, 910). Other element would receive the click: <div class="sticky-offer__container js_sticky-offers-container">...</div>
#   (Session info: chrome=147.0.7727.138); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#elementclickinterceptedexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff6213d37c5+15b35]
# 	chromedriver!GetHandleVerifier [0x7ff6213d3830+15ba0]
# 	chromedriver!(No symbol) [0x7ff62111d8dd]
# 	chromedriver!(No symbol) [0x7ff62117f175]
# 	chromedriver!(No symbol) [0x7ff62117c88a]
# 	chromedriver!(No symbol) [0x7ff621179715]
# 	chromedriver!(No symbol) [0x7ff6211785c7]
# 	chromedriver!(No symbol) [0x7ff62116b236]
# 	chromedriver!(No symbol) [0x7ff6211a002a]
# 	chromedriver!(No symbol) [0x7ff62116aab6]
# 	chromedriver!(No symbol) [0x7ff6211c4df3]
# 	chromedriver!(No symbol) [0x7ff621169348]
# 	chromedriver!(No symbol) [0x7ff62116a233]
# 	chromedriver!GetHandleVerifier [0x7ff6216c5e39+3081a9]
# 	chromedriver!GetHandleVerifier [0x7ff6216c054a+3028ba]
# 	chromedriver!GetHandleVerifier [0x7ff6216e17f2+323b62]
# 	chromedriver!GetHandleVerifier [0x7ff6213f0bd5+32f45]
# 	chromedriver!GetHandleVerifier [0x7ff6213fa1ec+3c55c]
# 	chromedriver!GetHandleVerifier [0x7ff6213dcb14+1ee84]
# 	chromedriver!GetHandleVerifier [0x7ff6213dccc6+1f036]
# 	chromedriver!GetHandleVerifier [0x7ff6213c0a77+2de7]
# 	KERNEL32!BaseThreadInitThunk [0x7ffc6b637374+14]
# 	ntdll!RtlUserThreadStart [0x7ffc6c9bcc91+21]

# %% [markdown]
# 8. Save acquired opinions

# %%
if not os.path.exists("./opinions"):
    os.mkdir("./opinions")

# %%
with open(f"./opinions/{product_code}.json", "w", encoding="utf-8") as f:
    json.dump(all_opinions,f, indent=4, ensure_ascii=False)
